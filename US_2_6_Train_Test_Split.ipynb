# %% [markdown]
# <a href="https://colab.research.google.com/github/SamFisher8/Telco-Customer-Churn-Analysis/blob/main/US_2_6_Train_Test_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SamFisher8/Telco-Customer-Churn-Analysis.git
# %cd Telco-Customer-Churn-Analysis
# Out:
# Cloning into 'Telco-Customer-Churn-Analysis'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 103 (delta 34), reused 27 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 278.25 KiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/Telco-Customer-Churn-Analysis

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load scaled dataset
df = pd.read_csv("Data_Preparation/data/processed/Dataset_Scaled_v1.csv")

df.shape
# Out:
# (6741, 11)

# %%
X = df.drop(columns=["Churn"])
y = df["Churn"]

print(X.shape, y.shape)
# Out:
# (6741, 10) (6741,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training set:", X_train.shape, y_train.shape)
print("Testing set:", X_test.shape, y_test.shape)
# Out:
# Training set: (5392, 10) (5392,)
# Testing set: (1349, 10) (1349,)

# %%
output_path = "Data_Preparation/data/processed/"

X_train.to_csv(output_path + "X_train.csv", index=False)
y_train.to_csv(output_path + "y_train.csv", index=False)

X_test.to_csv(output_path + "X_test.csv", index=False)
y_test.to_csv(output_path + "y_test.csv", index=False)

# %%
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# Churn
# 0    0.734236
# 1    0.265764
# Name: proportion, dtype: float64
# Churn
# 0    0.734618
# 1    0.265382
# Name: proportion, dtype: float64

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Data_Preparation/data/processed/X_test.csv
# 	new file:   Data_Preparation/data/processed/X_train.csv
# 	new file:   Data_Preparation/data/processed/y_test.csv
# 	new file:   Data_Preparation/data/processed/y_train.csv

# %%
pwd
# Out:
# '/content/Telco-Customer-Churn-Analysis'
